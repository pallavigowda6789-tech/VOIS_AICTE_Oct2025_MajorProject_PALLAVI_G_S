# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavigowda6789-tech/VOIS_AICTE_Oct2025_MajorProject_PALLAVI_G_S/blob/main/Netflix_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker

# %%
df = pd.read_csv('/content/Netflix Dataset.csv')

# %%
print("\nColumn Info:\n")
display(df.info())
# Out:
# Column Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB
# None

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'], format='mixed', dayfirst=False)

# %%
print(df.isnull().sum())
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   datetime64[ns]
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 730.0+ KB
# None

# %%
df = df[['Show_Id', 'Title', 'Category', 'Director', 'Country','Release_Date', 'Rating', 'Type', 'Duration']]

# %%
# Normalize text fields (lowercase, strip whitespace)
for col in ['Show_Id', 'Title', 'Category', 'Director', 'Country','Release_Date', 'Rating', 'Type']:
    if df[col].dtype == 'object':
        df[col] = df[col].str.lower().str.strip()

display(df.head())
# Out:
#   Show_Id  Title Category           Director        Country Release_Date  \
# 0      s1     3%  tv show                NaN         brazil   2020-08-14
# 1      s2  07:19    movie  jorge michel grau         mexico   2016-12-23
# 2      s3  23:59    movie       gilbert chan      singapore   2018-12-20
# 3      s4      9    movie        shane acker  united states   2017-11-16
# 4      s5     21    movie     robert luketic  united states   2020-01-01
#
#   Rating                                               Type   Duration
# 0  tv-ma  international tv shows, tv dramas, tv sci-fi &...  4 Seasons
# 1  tv-ma                       dramas, international movies     93 min
# 2      r                horror movies, international movies     78 min
# 3  pg-13  action & adventure, independent movies, sci-fi...     80 min
# 4  pg-13                                             dramas    123 min

# %%
# Convert 'Add_Month_Year' to datetime objects
monthly_counts['Add_Month_Year'] = pd.to_datetime(monthly_counts['Add_Month_Year'].astype(str))

plt.figure(figsize=(12, 6))
plt.plot(monthly_counts['Add_Month_Year'], monthly_counts['Movie'], label='Movie')

plt.xlabel('Year Added')
plt.ylabel('Number of Titles Added')
plt.title('Monthly Content Additions to Netflix (Movie)')

# Format x-axis to show only years
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
monthly_counts['Add_Month_Year'] = pd.to_datetime(monthly_counts['Add_Month_Year'].astype(str))

plt.figure(figsize=(12, 6))
plt.plot(monthly_counts['Add_Month_Year'], monthly_counts['TV Show'], label='TV Show')

plt.xlabel('Year Added')
plt.ylabel('Number of Titles Added')
plt.title('Monthly Content Additions to Netflix (TV Show)')

# Format x-axis to show only years
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Convert 'Add_Month_Year' to datetime objects
monthly_counts['Add_Month_Year'] = pd.to_datetime(monthly_counts['Add_Month_Year'].astype(str))

plt.figure(figsize=(12, 6))
plt.plot(monthly_counts['Add_Month_Year'], monthly_counts['Movie'], label='Movie')
plt.plot(monthly_counts['Add_Month_Year'], monthly_counts['TV Show'], label='TV Show')

plt.xlabel('Year Added')
plt.ylabel('Number of Titles Added')
plt.title('Monthly Content Additions to Netflix (Movies vs. TV Shows)')

# Format x-axis to show only years
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
category_counts = df['Category'].value_counts()
display(category_counts)
# Out:
# Category
# movie      5377
# tv show    2410
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
category_counts.plot(kind='bar')
plt.title('Distribution of Content Categories')
plt.xlabel('Category')
plt.ylabel('Number of Titles')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
top_10_countries = country_total_counts.head(10).index
country_category_counts_top_10 = country_category_counts.loc[top_10_countries]

country_category_counts_top_10.plot(kind='bar', stacked=True, figsize=(12, 7))
plt.title('Top 10 Countries by Content Type on Netflix')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Category')
plt.tight_layout()
plt.show()

# %%
# Extract all unique types from the 'Type' column
all_types = df['Type'].str.split(', ').explode().unique()
display(all_types)
# Out:
# array(['international tv shows', 'tv dramas', 'tv sci-fi & fantasy',
#        'dramas', 'international movies', 'horror movies',
#        'action & adventure', 'independent movies', 'sci-fi & fantasy',
#        'tv mysteries', 'thrillers', 'crime tv shows', 'docuseries',
#        'documentaries', 'sports movies', 'comedies', 'anime series',
#        'reality tv', 'tv comedies', 'romantic movies',
#        'romantic tv shows', 'science & nature tv', 'movies',
#        'british tv shows', 'korean tv shows', 'music & musicals',
#        'lgbtq movies', 'faith & spirituality', "kids' tv",
#        'tv action & adventure', 'spanish-language tv shows',
#        'children & family movies', 'tv shows', 'classic movies',
#        'cult movies', 'tv horror', 'stand-up comedy & talk shows',
#        'teen tv shows', 'stand-up comedy', 'anime features',
#        'tv thrillers', 'classic & cult tv'], dtype=object)

# %%
plt.figure(figsize=(16, 8)) # Increased figure size for more categories
type_counts.plot(kind='bar')
plt.title('Distribution of All Content Types on Netflix')
plt.xlabel('Content Type')
plt.ylabel('Number of titles')
plt.xticks(rotation=90, ha='center') # Rotate labels more for readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_10_highest_rated_countries.plot(kind='bar')
plt.title('Top 10 Countries with highest rating ')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the genre_df to include only titles from the top 10 highest rated countries
top_10_rated_countries_genre_df = genre_df[genre_df['Country'].isin(top_10_highest_rated_countries.index)]

# Count the occurrences of each genre within the top 10 highest rated countries
top_10_rated_countries_genre_counts = top_10_rated_countries_genre_df['Genre'].value_counts()

# Display the top genres within these countries
display(top_10_rated_countries_genre_counts.head(10))
# Out:
# Genre
# dramas                      1897
# international movies        1771
# comedies                    1292
# documentaries                734
# independent movies           698
# action & adventure           680
# international tv shows       677
# children & family movies     535
# thrillers                    528
# tv dramas                    431
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
top_10_rated_countries_genre_counts.head(10).plot(kind='bar')
plt.title('Top 10 Genres in Top 10 Countries with Highest Rated Content')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Extract the release year from the 'Release_Date'
df['Release_Year'] = df['Release_Date'].dt.year

# Explode the 'Type' column to have one genre per row
genre_df = df.assign(Genre=df['Type'].str.split(', ')).explode('Genre')

display(genre_df.head())
# Out:
#   Show_Id  Title Category           Director Country Release_Date Rating  \
# 0      s1     3%  tv show                NaN  brazil   2020-08-14  tv-ma
# 0      s1     3%  tv show                NaN  brazil   2020-08-14  tv-ma
# 0      s1     3%  tv show                NaN  brazil   2020-08-14  tv-ma
# 1      s2  07:19    movie  jorge michel grau  mexico   2016-12-23  tv-ma
# 1      s2  07:19    movie  jorge michel grau  mexico   2016-12-23  tv-ma
#
#                                                 Type   Duration  Release_Year  \
# 0  international tv shows, tv dramas, tv sci-fi &...  4 Seasons        2020.0
# 0  international tv shows, tv dramas, tv sci-fi &...  4 Seasons        2020.0
# 0  international tv shows, tv dramas, tv sci-fi &...  4 Seasons        2020.0
# 1                       dramas, international movies     93 min        2016.0
# 1                       dramas, international movies     93 min        2016.0
#
#                     Genre
# 0  international tv shows
# ...

# %%
# Identify the top genres based on total counts
top_genres = genre_total_counts.head(10).index
display(top_genres)
# Out:
# Index(['international movies', 'dramas', 'comedies', 'international tv shows',
#        'documentaries', 'action & adventure', 'independent movies',
#        'tv dramas', 'thrillers', 'children & family movies'],
#       dtype='object', name='Genre')

# %%
# Filter the genre_yearly_counts to include only the top genres
top_genre_yearly_counts = genre_yearly_counts[top_genres]

# Plot the trends of the top genres over the release years
plt.figure(figsize=(14, 8))
for genre in top_genres:
    plt.plot(top_genre_yearly_counts.index, top_genre_yearly_counts[genre], label=genre)

plt.title('Trends of Top 10 Genres Over Release Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Iterate through each year and plot a bar chart for its genre distribution
for year in genre_yearly_counts.index:
    genre_counts_this_year = genre_yearly_counts.loc[year].sort_values(ascending=False)

    plt.figure(figsize=(12, 6))
    genre_counts_this_year.head(10).plot(kind='bar') # Plotting top 10 for readability
    plt.title(f'Top 10 Genre Distribution for Release Year {int(year)}')
    plt.xlabel('Genre')
    plt.ylabel('Number of Titles')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Explode the 'Type' column for movies to get individual genres
movies_genre_df = movies_df.assign(Genre=movies_df['Type'].str.split(', ')).explode('Genre')

# Group by genre and calculate the sum of duration
movie_genre_total_duration = movies_genre_df.groupby('Genre')['Duration_minutes'].sum().sort_values(ascending=False)

display(movie_genre_total_duration.head())
# Out:
# Genre
# international movies    270027.0
# dramas                  238781.0
# comedies                153795.0
# action & adventure       81677.0
# independent movies       67808.0
# Name: Duration_minutes, dtype: float64

# %%
# Explode the 'Type' column in the highest_rated_df to get individual genres
highest_rated_genre_df = highest_rated_df.assign(Genre=highest_rated_df['Type'].str.split(', ')).explode('Genre')

# Count the occurrences of each genre in the highest rated content
highest_rated_genre_counts = highest_rated_genre_df['Genre'].value_counts()

# Display the top 10 genres in the highest rating categories
display(highest_rated_genre_counts.head(10))

# Plot a horizontal bar chart of the top 10 genres in highest rating categories
plt.figure(figsize=(12, 6))
highest_rated_genre_counts.head(10).plot(kind='barh')
plt.title('Top 10 Genres in Highest Rating Categories in overall')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()
# Out:
# Genre
# international movies      1944
# dramas                    1618
# comedies                   926
# international tv shows     917
# independent movies         582
# tv dramas                  581
# action & adventure         526
# documentaries              484
# thrillers                  427
# crime tv shows             388
# Name: count, dtype: int64
